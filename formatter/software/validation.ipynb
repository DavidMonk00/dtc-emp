# %%
import pandas as pd

# %%
cpp = pd.read_csv("c++/output.txt")
vhdl = pd.read_csv("sim/output.txt")

# %%
vhdl
# Out:
#      header             data
# 0         0  511724617533798
# 1         5  476470251657561
# 2         1  194995827386728
# 3         7  441425684887895
# 4         7  441355873519974
# 5         5  441460615133529
# 6         7   54362525952358
# 7         1  230249541859671
# 8         4  546978480974183
# 9         4  265503823788375
# 10        4  124696524228966
# 11        4  160020534827355
# 12        0  511828804290920
# 13        7   19213219739991
# 14        1  124592421276010
# 15        1  371056940095831
# 16        4  195100013570406
# 17        4  300758022977883
# 18        3  406171500652902
# 19        4  547013730376025
# 20        5  300583638772071
# 21        2  547013730621785
# 22        0  195100014430566
# 23        1  124801266047321
# 24        3  230284386642278
# 25        3  194960379197787
# 26        2  476609736059239
# 27        2   89581964081495
# 28        5  265329926080874
# 29        3  124836162369883
# ..      ...              ...
# ...

# %%
for i in (cpp.data - vhdl.data).values:
    print(bin(int(i)))
# Out:
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# 0b0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3cd5223e544c> in <module>
#       1 for i in (cpp.data - vhdl.data).values:
# ----> 2     print(bin(int(i)))
#
# ...
